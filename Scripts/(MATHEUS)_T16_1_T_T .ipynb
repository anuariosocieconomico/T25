# %%
#INSTALANDO BIBLIOTECAS NECESSÁRIAS
# !pip install -U sidrapy
#!pip install requests
import sidrapy
import pandas as pd
#from scipy import stats
#import plotly.express as px
#import plotly.graph_objects as go
import numpy as np
#import matplotlib.pyplot as plt

# %%
#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES
SE1 = sidrapy.get_table(table_code="6821",variable = "9784/C63/4342", territorial_level="3", ibge_territorial_code="28", period="all")
SE1 = SE1.iloc[1:, [8,6,4]]
SE1.columns = ['ANO','REGIÃO','PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES']
SE1

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES
NE1 = sidrapy.get_table(table_code="6821",variable = "9784/C63/4342", territorial_level="2", ibge_territorial_code="2", period="all")
NE1 = NE1.iloc[1:, [8,6,4]]
NE1.columns = ['ANO','REGIÃO','PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES']
NE1

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES
BR1 = sidrapy.get_table(table_code="6821",variable = "9784/C63/4342", territorial_level="1", ibge_territorial_code="1", period="all")
BR1 = BR1.iloc[1:, [8,6,4]]
BR1.columns = ['ANO','REGIÃO','PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES']
BR1

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES
SE2 = sidrapy.get_table(table_code="6734",variable = "9984/C1/6795", territorial_level="3", ibge_territorial_code="28", period="all")
SE2 = SE2.iloc[1:, [8,6,4]]
SE2.columns = ['ANO','REGIÃO','COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES']
SE2

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES
NE2 = sidrapy.get_table(table_code="6734",variable = "9984/C1/6795", territorial_level="2", ibge_territorial_code="2", period="all")
NE2 = NE2.iloc[1:, [8,6,4]]
NE2.columns = ['ANO','REGIÃO','COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES']
NE2

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES
BR2 = sidrapy.get_table(table_code="6734",variable = "9984/C1/6795", territorial_level="1", ibge_territorial_code="1", period="all")
BR2 = BR2.iloc[1:, [8,6,4]]
BR2.columns = ['ANO','REGIÃO','COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES']
BR2

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - ABASTECIDOS POR REDE GERAL DE ÁGUA
SE3 = sidrapy.get_table(table_code="6731",variable = "9784/C1/6795/C825/46285", territorial_level="3", ibge_territorial_code="28", period="all")
SE3 = SE3.iloc[1:, [8,6,4]]
SE3.columns = ['ANO','REGIÃO','ABASTECIDOS POR REDE GERAL DE ÁGUA']
SE3

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - ABASTECIDOS POR REDE GERAL DE ÁGUA
NE3 = sidrapy.get_table(table_code="6731",variable = "9784/C1/6795/C825/46285", territorial_level="2", ibge_territorial_code="2", period="all")
NE3 = NE3.iloc[1:, [8,6,4]]
NE3.columns = ['ANO','REGIÃO','ABASTECIDOS POR REDE GERAL DE ÁGUA']
NE3

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - ABASTECIDOS POR REDE GERAL DE ÁGUA
BR3 = sidrapy.get_table(table_code="6731",variable = "9784/C1/6795/C825/46285", territorial_level="1", ibge_territorial_code="1", period="all")
BR3 = BR3.iloc[1:, [8,6,4]]
BR3.columns = ['ANO','REGIÃO','ABASTECIDOS POR REDE GERAL DE ÁGUA']
BR3

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL
SE4 = sidrapy.get_table(table_code="6735",variable = "9988/C1/6795/C11558/46290", territorial_level="3", ibge_territorial_code="28", period="all")
SE4 = SE4.iloc[1:, [8,6,4]]
SE4.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
SE4

#2019 E 2022

SE4_2019 = sidrapy.get_table(table_code="7192",variable = "9988/C1/6795/C11558/47930", territorial_level="3", ibge_territorial_code="28", period="all")
SE4_2019 = SE4_2019.iloc[1:, [8,6,4]]
SE4_2019.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
SE4_2019

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL
NE4 = sidrapy.get_table(table_code="6735",variable = "9988/C1/6795/C11558/46290", territorial_level="2", ibge_territorial_code="2", period="all")
NE4 = NE4.iloc[1:, [8,6,4]]
NE4.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
NE4

#2019 E 2022

NE4_2019 = sidrapy.get_table(table_code="7192",variable = "9988/C1/6795/C11558/47930", territorial_level="2", ibge_territorial_code="2", period="all")
NE4_2019 = NE4_2019.iloc[1:, [8,6,4]]
NE4_2019.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
NE4_2019

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1
BR4 = sidrapy.get_table(table_code="6735",variable = "9988/C1/6795/C11558/46290", territorial_level="1", ibge_territorial_code="1", period="all")
BR4 = BR4.iloc[1:, [8,6,4]]
BR4.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
BR4

#2019 E 2022

BR4_2019 = sidrapy.get_table(table_code="7192",variable = "9988/C1/6795/C11558/47930", territorial_level="1", ibge_territorial_code="1", period="all")
BR4_2019 = BR4_2019.iloc[1:, [8,6,4]]
BR4_2019.columns = ['ANO','REGIÃO','COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL']
BR4_2019

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)
SE5 = sidrapy.get_table(table_code="6736",variable = "9784/C1/6795/C67/4661", territorial_level="3", ibge_territorial_code="28", period="all")
SE5 = SE5.iloc[1:, [8,6,4]]
SE5.columns = ['ANO','REGIÃO','ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)']
SE5

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)
NE5 = sidrapy.get_table(table_code="6736",variable = "9784/C1/6795/C67/4661", territorial_level="2", ibge_territorial_code="2", period="all")
NE5 = NE5.iloc[1:, [8,6,4]]
NE5.columns = ['ANO','REGIÃO','ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)']
NE5

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)
BR5 = sidrapy.get_table(table_code="6736",variable = "9784/C1/6795/C67/4661", territorial_level="1", ibge_territorial_code="1", period="all")
BR5 = BR5.iloc[1:, [8,6,4]]
BR5.columns = ['ANO','REGIÃO','ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)']
BR5

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL
SE6 = sidrapy.get_table(table_code="6737",variable = "5074/C1/6795/C827/46297", territorial_level="3", ibge_territorial_code="28", period="all")
SE6 = SE6.iloc[1:, [8,6,4]]
SE6.columns = ['ANO','REGIÃO','COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL']
SE6

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL
NE6 = sidrapy.get_table(table_code="6737",variable = "5074/C1/6795/C827/46297", territorial_level="2", ibge_territorial_code="2", period="all")
NE6 = NE6.iloc[1:, [8,6,4]]
NE6.columns = ['ANO','REGIÃO','COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL']
NE6

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL
BR6 = sidrapy.get_table(table_code="6737",variable = "5074/C1/6795/C827/46297", territorial_level="1", ibge_territorial_code="1", period="all")
BR6 = BR6.iloc[1:, [8,6,4]]
BR6.columns = ['ANO','REGIÃO','COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL']
BR6

#PEGANDO OS DADOS DE SERGIPE DO GRAFICO T16.1 - COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS
SE7 = sidrapy.get_table(table_code="6739",variable = "10250/C828/46298", territorial_level="3", ibge_territorial_code="28", period="all")
SE7 = SE7.iloc[1:, [8,6,4]]
SE7.columns = ['ANO','REGIÃO','COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS']
SE7

#PEGANDO OS DADOS DO NORDESTE DO GRAFICO T16.1 - COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS
NE7 = sidrapy.get_table(table_code="6739",variable = "10250/C828/46298", territorial_level="2", ibge_territorial_code="2", period="all")
NE7 = NE7.iloc[1:, [8,6,4]]
NE7.columns = ['ANO','REGIÃO','COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS']
NE7

#PEGANDO OS DADOS DO BRASIL DO GRAFICO T16.1 - COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS
BR7 = sidrapy.get_table(table_code="6739",variable = "10250/C828/46298", territorial_level="1", ibge_territorial_code="1", period="all")
BR7 = BR7.iloc[1:, [8,6,4]]
BR7.columns = ['ANO','REGIÃO','COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS']
BR7

#JUNTANDO TODAS AS TABELAS E CONFIGURANDO O FORMATO DAS VARIÁVEIS NUMÉRICAS

T16P1_1 = pd.concat([SE1, NE1,BR1])
T16P1_1['ANO'] = T16P1_1['ANO'].astype(np.int64)
T16P1_1['PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES'] = T16P1_1['PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES'].astype(float)

T16P1_2 = pd.concat([SE2, NE2, BR2])
T16P1_2['ANO'] = T16P1_2['ANO'].astype(np.int64)
T16P1_2['COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES'] = T16P1_2['COM BANHEIRO OU SANITÁRIO DE USO EXCLUSIVO DOS MORADORES'].astype(float)

T16P1_3 = pd.concat([SE3,NE3,BR3])
T16P1_3['ANO'] = T16P1_3['ANO'].astype(np.int64)
T16P1_3['ABASTECIDOS POR REDE GERAL DE ÁGUA'] = T16P1_3['ABASTECIDOS POR REDE GERAL DE ÁGUA'].astype(float)

T16P1_4 = pd.concat([SE4,SE4_2019,NE4,NE4_2019,BR4,BR4_2019])
T16P1_4['ANO'] = T16P1_4['ANO'].astype(np.int64)
T16P1_4['COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL'] = T16P1_4['COM ESGOTAMENTO POR REDE COLETORA DE ESGOTO OU PLUVIAL'].astype(float)

T16P1_5 = pd.concat([SE5,NE5,BR5])
T16P1_5['ANO'] = T16P1_5['ANO'].astype(np.int64)
T16P1_5['ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)'] = T16P1_5['ATENDIDOS POR SERVIÇO DE COLETA DE LIXO (DIRETA OU INDIRETA)'].astype(float)

T16P1_6 = pd.concat([SE6,NE6,BR6])
T16P1_6['ANO'] = T16P1_6['ANO'].astype(np.int64)
T16P1_6['COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL'] = T16P1_6['COM ENERGIA ELÉTRICA FORNECIDA POR REDE GERAL'].astype(float)

T16P1_7 = pd.concat([SE7,NE7,BR7])
T16P1_7['ANO'] = T16P1_7['ANO'].astype(np.int64)
T16P1_7['COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS'] = T16P1_7['COM GÁS DE BOTIJÃO, OU ENCANADO, COMO COMBUSTÍVEL PARA PREPARO DE ALIMENTOS'].astype(float)


A = pd.merge(T16P1_1, T16P1_2, how = 'outer')
A1 = pd.merge(A, T16P1_3, how = 'outer')
A2 = pd.merge(A1, T16P1_4, how = 'outer')
A3 = pd.merge(A2, T16P1_5, how = 'outer')
A4 = pd.merge(A3, T16P1_6, how = 'outer')
A5 = pd.merge(A4, T16P1_7, how = 'outer')
A5

T16_1 = A5


#EXPORTANDO PARA EXCEL E CSV

T16_1.to_excel('T16_1.xlsx', index=False)
T16_1.to_csv('T16_1.csv', sep=';', index=False, encoding='latin1', decimal=',')

#VISUALIZANDO
T16_1
# Out:
#      ANO    REGIÃO  PROPORÇÃO (%) DE DOMICÍLIOS PARTICULARES PERMANENTES  \
# 0   2016   Sergipe                                               72.8
# 1   2017   Sergipe                                               71.3
# 2   2018   Sergipe                                               68.6
# 3   2019   Sergipe                                               64.1
# 4   2022   Sergipe                                               61.8
# 5   2016  Nordeste                                               73.0
# 6   2017  Nordeste                                               73.1
# 7   2018  Nordeste                                               71.5
# 8   2019  Nordeste                                               72.4
# 9   2022  Nordeste                                               71.0
# 10  2016    Brasil                                               66.7
# 11  2017    Brasil                                               66.5
# ...
